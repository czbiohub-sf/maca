# %%
import pandas as pd
import os

from maca import clean_annotation, clean_labels

metadata_folder = os.path.join('..', 'metadata' )

annotation_folder = os.path.join(metadata_folder, 'manual_annotations')
# annotation_folder

summary_folder = os.path.join(metadata_folder, 'summary')
! mkdir $summary_folder

# %load_ext autoreload
# %autoreload 2
# Out:
# mkdir: ../metadata/summary: File exists

# %%
from maca import clean_annotation, clean_labels
import glob
import os

dfs = []

original_dfs = []

# cleaned_tissues = 'Bladder', 'Kidney', 'Liver', 'Lung'

skip_tissues = [] #'Trachea'

globber = os.path.join(annotation_folder, '*', '*.csv')


for csv in glob.glob(globber):
    if '10x' not in csv.lower():
        continue
    basename = os.path.basename(csv)
    if basename == 'MACA_Metadata.csv':
        continue
    tissue = os.path.dirname(csv).split('/')[-1]
    if tissue.startswith('annotation_cleaning_double_check'):
        continue
        
    # Skip Tongue for now because the annotation is the same as the plates
#     if tissue in skip_tissues:
#         continue

        
    print('\n-', tissue,  '-')
    if tissue == "Lung":
        df = pd.read_csv(csv, usecols=["V1", "V2"], index_col=0)
        df.columns = ['annotation']
#         brea
    else:
        df = pd.read_csv(csv, index_col=0)
#     print('\t', '\n\t'.join(df['annotation'].astype(str).unique()))
    try:
        sizes = df.fillna('.').groupby(['annotation', 'subannotation']).size()
    except KeyError:
        try:
            sizes = df.fillna('.').groupby(['annotation']).size()
#             print('-- before cleaning --\n', )
        except KeyError:
            sizes = df.head()
            print('-- no "annotation" or "subannotation" columns --', )
            
    print('-- before cleaning --\n', sizes)
    
    original_dfs.append(df)
    
    df = clean_annotation(df, tissue, debug=True)
    sizes = df.fillna('..').groupby(['annotation', 'subannotation']).size()
    print('--- after cleaning ---\n', sizes)
    df['tissue'] = tissue
    
#     if tissue in cleaned_tissues:
    dfs.append(df)
    
    
combined = pd.concat(dfs)

# Remove Heart annotation of Aorta cells. 
# "Heart" comes after "Aorta" alphabetically so we're using 
# "drop_duplicates" which keeps only the first occurence
# combined = combined.loc[~combined.index.duplicated()]

combined['annotation_subannotation'] = combined.apply(
    lambda x: '{annotation}: {subannotation}'.format(**x) 
    if pd.notnull(x['subannotation']) else x['annotation'], axis=1)

combined.head()
# Out:
# - Bladder -
# -- before cleaning --
#  annotation         subannotation
# Basal              .                266
# Endothelial cells  .                 68
# Immune cells       .                 57
# LuminalA1          .                313
# LuminalA2          .                219
# LuminalB           .                391
# MesenchymalA1      .                169
# MesenchymalA2      .                501
# MesenchymalB1      .                187
# MesenchymalB2      .                329
# dtype: int64
# 		--- after cleaning labels ---
# annotation         subannotation
# basal              -                266
# endothelial_cells  -                 68
# immune_cells       -                 57
# luminala           -                532
# luminalb           -                391
# mesenchymala       -                670
# mesenchymalb       -                516
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation         subannotation
# basal cells        -                266
# endothelial_cells  -                 68
# immune_cells       -                 57
# luminal cells      a                532
#                    b                391
# mesenchymal cells  a                670
#                    b                516
# dtype: int64
# --- after cleaning ---
#  annotation   subannotation
# basal        ..               266
# endothelial  ..                68
# immune       ..                57
# luminal      a                532
#              b                391
# mesenchymal  a                670
#              b                516
# dtype: int64
#
# - Heart -
# -- before cleaning --
#  annotation             subannotation
# Blood_Cells            .                       55
# CMs                    .                       83
# Coronary_vascular_EDC  .                      178
# Endocardial_EDC        .                       65
# Fb                     .                      157
# Fb_SMC                 Fibroblast              65
#                        Smooth_Muscle_Cells     21
# dtype: int64
# 		--- after cleaning labels ---
# annotation             subannotation
# blood_cells            -                       55
# cms                    -                       83
# coronary_vascular_edc  -                      178
# endocardial_edc        -                       65
# fb                     -                      157
# fb_smc                 fibroblast              65
#                        smooth_muscle_cells     21
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation           subannotation
# cardiomyocytes       -                     83
# endothelial_cells    coronary_vascular    178
#                      endocardial           65
# erythrocytes         -                     55
# fibroblasts          -                    222
# smooth_muscle_cells  -                     21
# dtype: int64
# --- after cleaning ---
#  annotation      subannotation
# cardiomyocytes  ..                    83
# endothelial     coronary_vascular    178
#                 endocardial           65
# erythrocytes    ..                    55
# fibroblasts     ..                   222
# smooth_muscle   ..                    21
# dtype: int64
#
# - Kidney -
# -- before cleaning --
#  annotation                   subannotation
# Collecting duct cells        .                 72
# Feneserated capillary cells  .                345
# Fibroblasts                  .                113
# Macrophages                  .                181
# Proximal ascending tubule    .                352
# Smooth muscle cells          .                 50
# Thick Ascending tubule       .                473
# connecting tubule cells      .                245
# endothelial cells            .                 45
# other immune                 .                 54
# proximal tubule              .                851
# dtype: int64
# 		--- after cleaning labels ---
# annotation                   subannotation
# collecting_duct_cells        -                 72
# connecting_tubule_cells      -                245
# endothelial_cells            -                 45
# feneserated_capillary_cells  -                345
# fibroblasts                  -                113
# macrophages                  -                181
# other_immune                 -                 54
# proximal_ascending_tubule    -                352
# proximal_tubule              -                851
# smooth_muscle_cells          -                 50
# thick_ascending_tubule       -                473
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation                   subannotation
# collecting_duct_cells        -                       72
# endothelial_cells            -                       45
# fenestrated_capillary_cells  -                      345
# fibroblasts                  -                      113
# immune_cells                 -                       54
# macrophages                  -                      181
# smooth_muscle_cells          -                       50
# tubule_cells                 connecting_            245
#                              proximal_              851
#                              proximal_ascending_    352
#                              thick_ascending_       473
# dtype: int64
# --- after cleaning ---
#  annotation             subannotation
# collecting_duct        ..                     72
# endothelial            ..                     45
# fenestrated_capillary  ..                    345
# fibroblasts            ..                    113
# immune                 ..                     54
# macrophages            ..                    181
# smooth_muscle          ..                     50
# tubule                 connecting            245
#                        proximal              851
#                        proximal_ascending    352
#                        thick_ascending       473
# dtype: int64
#
# - Liver -
# -- before cleaning --
#  annotation         subannotation
# F-hep-midlobule    F-Hamp-high        50
# F-hep-pericentral  F-Cyp2e1, Glul    258
# F-hep-periportal   F-Cyp2f2          203
# M-hep-midlobule    M-Mup-high        214
# M-hep-pericentral  M-Cyp2e1, Glul    115
# M-hep-periportal   M-Cyp2f2          166
# endothelial        .                  20
# dtype: int64
# 		--- after cleaning labels ---
# annotation         subannotation
# endothelial        -                  20
# f-hep-midlobule    f-hamp-high        50
# f-hep-pericentral  f-cyp2e1,_glul    258
# f-hep-periportal   f-cyp2f           203
# m-hep-midlobule    m-mup-high        214
# m-hep-pericentral  m-cyp2e1,_glul    115
# m-hep-periportal   m-cyp2f           166
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation   subannotation
# endothelial  -                 20
# hepatocytes  midlobular       264
#              pericentral      373
#              periportal       369
# dtype: int64
# --- after cleaning ---
#  annotation   subannotation
# endothelial  ..                20
# hepatocytes  midlobular       264
#              pericentral      373
#              periportal       369
# dtype: int64
#
# - Lung -
# -- before cleaning --
#  annotation
# Alveolar Macrophages                                                   345
# B Cells                                                                205
# Ciliated Cells                                                          41
# Club Cells                                                               5
# Dendritic Cells                                                        225
# Endothelial Cell Type I                                                349
# Endothelial Cell Type IV                                                76
# Interstital Macrophages                                                111
# Mast Cells                                                              22
# Mesothelial Cells                                                       24
# Monocytes                                                              145
# Natural Killer Cells                                                   832
# Potential Ciliated and Club Cell Doublets                                8
# Potential Stromal Cell Type V and Endothelial Cell Type I Doublets      41
# Stromal Cell Type I                                                   1586
# Stromal Cell Type II                                                   466
# Stromal Cell Type IV                                                   348
# Stromal Cell Type V                                                    134
# T Cells                                                                246
# Type II Alveolar Epithelial Cells                                       89
# Unknown Immune I                                                       124
# Unknown Immune II                                                       27
# dtype: int64
# 		--- after cleaning labels ---
# annotation
# alveolar_macrophages                                                   345
# b_cells                                                                205
# ciliated_cells                                                          41
# club_cells                                                               5
# dendritic_cells                                                        225
# endothelial_cell_type_i                                                349
# endothelial_cell_type_iv                                                76
# interstital_macrophages                                                111
# mast_cells                                                              22
# mesothelial_cells                                                       24
# monocytes                                                              145
# natural_killer_cells                                                   832
# potential_ciliated_and_club_cell_doublets                                8
# potential_stromal_cell_type_v_and_endothelial_cell_type_i_doublets      41
# stromal_cell_type_i                                                   1586
# stromal_cell_type_ii                                                   466
# stromal_cell_type_iv                                                   348
# stromal_cell_type_v                                                    134
# t_cells                                                                246
# type_ii_alveolar_epithelial_cells                                       89
# unknown_immune_i                                                       124
# unknown_immune_ii                                                       27
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation            subannotation
# b_cells               -                    205
# ciliated_cells        -                     41
# club_cells            -                      5
# dendritic_cells       -                    225
# endothelial_cells     -                    425
# epithelial_cells      alveolar_type_ii      89
# immune_cells          -                    151
# macrophages           alveolar             345
#                       interstitial         111
# mast_cells            -                     22
# mesothelial_cells     -                     24
# monocytes             -                    145
# natural_killer_cells  -                    832
# stromal_cells         -                   2534
# t_cells               -                    246
# unknown               -                     49
# dtype: int64
# --- after cleaning ---
#  annotation      subannotation
# b_cells         ..                   205
# ciliated        ..                    41
# club            ..                     5
# dendritic       ..                   225
# endothelial     ..                   425
# epithelial      alveolar_type_ii      89
# immune          ..                   151
# macrophages     alveolar             345
#                 interstitial         111
# mast            ..                    22
# mesothelial     ..                    24
# monocytes       ..                   145
# natural_killer  ..                   832
# stromal         ..                  2534
# t_cells         ..                   246
# unknown         ..                    49
# dtype: int64
#
# - Mammary -
# -- before cleaning --
#  annotation                                   subannotation
# B cells                                      .                 764
# Basal Epithelial cells                       .                 393
# Endothelial cells                            .                 251
# Hormone responsive luminal epithelial cells  .                 190
# Luminal epithelial progenitors Cd14+         .                 240
# Macrophages                                  .                 186
# S100a4+/Ccl5+ cells                          .                  57
# Stromal cells                                .                 581
# Stromal cells Mustn1+/Procr+                 .                  59
# T cells                                      .                1467
# T cells Nkg7+                                .                 293
# dtype: int64
# 		--- after cleaning labels ---
# annotation                                   subannotation
# b_cells                                      -                 764
# basal_epithelial_cells                       -                 393
# endothelial_cells                            -                 251
# hormone_responsive_luminal_epithelial_cells  -                 190
# luminal_epithelial_progenitors_cd14+         -                 240
# macrophages                                  -                 186
# s100a4+/ccl5+_cells                          -                  57
# stromal_cells                                -                 581
# stromal_cells_mustn1+/procr+                 -                  59
# t_cells                                      -                1467
# t_cells_nkg7+                                -                 293
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation         subannotation
# b_cells            -                      764
# basal_cells        -                      393
# endothelial_cells  -                      251
# luminal_cells      hormone_responsive     190
#                    progenitors            240
# macrophages        -                      186
# stromal_cells      -                      581
#                    mustn1+_and_procr+      59
#                    s100a4+_and_ccl5+       57
# t_cells            -                     1467
#                    nkg7+                  293
# dtype: int64
# --- after cleaning ---
#  annotation   subannotation
# b_cells      ..                     764
# basal        ..                     393
# endothelial  ..                     251
# luminal      hormone_responsive     190
#              progenitors            240
# macrophages  ..                     186
# stromal      ..                     581
#              mustn1+_and_procr+      59
#              s100a4+_and_ccl5+       57
# t_cells      ..                    1467
#              nkg7+                  293
# dtype: int64
#
# - Marrow -
# -- before cleaning --
#  annotation                           subannotation
# Erythrocytes                         .                142
# Erythroid-progenitors_Erythroblasts  .                268
# Granulocyte-progenitors              .                330
# Granulocytes                         .                770
# Immature-B                           .                299
# Macrophages                          .                222
# Mature-B                             .                 91
# Megakaryocyte-progenitors            .                 62
# Monocyte-progenitors                 .                322
# Monocytes                            .                522
# PreproB                              .                 63
# Stem_Progenitors                     .                399
# T_NKT                                .                162
# dtype: int64
# 		--- after cleaning labels ---
# annotation                           subannotation
# erythrocytes                         -                142
# erythroid-progenitors_erythroblasts  -                268
# granulocyte-progenitors              -                330
# granulocytes                         -                770
# immature-b                           -                299
# macrophages                          -                222
# mature-b                             -                 91
# megakaryocyte-progenitors            -                 62
# monocyte-progenitors                 -                322
# monocytes                            -                522
# preprob                              -                 63
# stem_progenitors                     -                399
# t_nkt                                -                162
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation    subannotation
# b_cells       immature         299
#               mature            91
#               prepro            63
# erythrocytes  -                142
# granulocytes  -                770
# macrophages   -                222
# monocytes     -                522
# progenitors   -                399
#               erythroid        268
#               granulocyte      330
#               mature           322
#               megakaryocyte     62
# t_cells       -                162
# dtype: int64
# --- after cleaning ---
#  annotation    subannotation
# b_cells       immature         299
#               mature            91
#               prepro            63
# erythrocytes  ..               142
# granulocytes  ..               770
# macrophages   ..               222
# monocytes     ..               522
# progenitors   ..               399
#               erythroid        268
#               granulocyte      330
#               mature           322
#               megakaryocyte     62
# t_cells       ..               162
# dtype: int64
#
# - Muscle -
# -- before cleaning --
#  annotation                     subannotation
# .                              .                 312
# B cells                        .                 463
# T cells                        .                 323
# chondrogenic cells             .                 380
# endothelial cells              .                1290
# fibro-/adipogenic progenitors  .                1111
# macrophages                    .                 308
# satellite cells                .                 349
# dtype: int64
# 		--- after cleaning labels ---
# annotation                     subannotation
# -                              -                 312
# b_cells                        -                 463
# chondrogenic_cells             -                 380
# endothelial_cells              -                1290
# fibro-/adipogenic_progenitors  -                1111
# macrophages                    -                 308
# satellite_cells                -                 349
# t_cells                        -                 323
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation              subannotation
# b_cells                 -                 463
# chondrogenic_cells      -                 380
# endothelial_cells       -                1290
# macrophages             -                 308
# mesenchymal_stem_cells  -                1111
# satellite_cells         -                 349
# t_cells                 -                 323
# unknown                 -                 312
# dtype: int64
# --- after cleaning ---
#  annotation        subannotation
# b_cells           ..                463
# chondrogenic      ..                380
# endothelial       ..               1290
# macrophages       ..                308
# mesenchymal_stem  ..               1111
# satellite         ..                349
# t_cells           ..                323
# unknown           ..                312
# dtype: int64
#
# - Spleen -
# -- before cleaning --
#  annotation                        subannotation
# 10. Dendritic cells               .                 102
# 11. Proliferative B cells         .                  98
# 12. Macrophages 2                 .                  96
# 13 T cells                        .                  92
# 14. Plasmocytoid Dendritic cells  .                  42
# 2. Marginal Zone B cells          .                1440
# 3. CD8+ T Cells                   .                 946
# 4. Cd4+ T cells                   .                 905
# 6. Macrophages 1                  .                 299
# 7. B cells                        .                 282
# 8. Natural Killer cells           .                 224
# 9. iNK cells                      .                 120
# T1/T2/Follicular B cells          .                4906
# dtype: int64
# 		--- after cleaning labels ---
# annotation                    subannotation
# b_cells                       -                 282
# cd4+_t_cells                  -                 905
# cd8+_t_cells                  -                 946
# dendritic_cells               -                 102
# ink_cells                     -                 120
# macrophages                   -                 395
# marginal_zone_b_cells         -                1440
# natural_killer_cells          -                 224
# plasmocytoid_dendritic_cells  -                  42
# proliferative_b_cells         -                  98
# t1/t2/follicular_b_cells      -                4906
# t_cells                       -                  92
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation       subannotation
# b_cells          -                            282
#                  follicular                  4906
#                  marginal_zone               1440
#                  proliferative                 98
# dendritic_cells  -                            102
#                  plasmocytoid                  42
# macrophages      -                            395
# t_cells          -                             92
#                  cd4+                         905
#                  cd8+                         946
#                  invariant_natural_killer     120
#                  natural_killer_cells         224
# dtype: int64
# --- after cleaning ---
#  annotation   subannotation
# b_cells      ..                           282
#              follicular                  4906
#              marginal_zone               1440
#              proliferative                 98
# dendritic    ..                           102
#              plasmocytoid                  42
# macrophages  ..                           395
# t_cells      ..                            92
#              cd4+                         905
#              cd8+                         946
#              invariant_natural_killer     120
#              natural_killer_cells         224
# dtype: int64
#
# - Thymus -
# -- before cleaning --
#  annotation                  subannotation
# DN-Stage 4c                 .                                        43
# DN-Stage3                   .                                        35
# DN-Stage4b                  .                                       211
# immature SP Cd8             .                                       194
# mix of cells                Single positive Cd8, possibly mature    117
#                             stromal_mesenchymal cells                81
# stromal mesenchymal cell    .                                        31
# thymocyte-DP                .                                       381
# thymocyte-DP-proliferating  .                                       336
# dtype: int64
# 		--- after cleaning labels ---
# annotation                  subannotation
# dn-stage3                   -                                        35
# dn-stage4b                  -                                       211
# dn-stage_4c                 -                                        43
# immature_sp_cd8             -                                       194
# mix_of_cells                single_positive_cd8,_possibly_mature    117
#                             stromal_mesenchymal_cells                81
# stromal_mesenchymal_cell    -                                        31
# thymocyte-dp                -                                       381
# thymocyte-dp-proliferating  -                                       336
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation                 subannotation
# stromal_mesenchymal_cells  -                                        112
# t_cells                    -double_positive                         381
#                            -double_positive-proliferating           336
#                            double_negative-stage3                    35
#                            double_negative-stage4b                  211
#                            double_negative-stage4c                   43
#                            immature_single_positive_cd8+            194
#                            single_positive_cd8+,_possibly_mature    117
# dtype: int64
# --- after cleaning ---
#  annotation           subannotation
# stromal_mesenchymal  ..                                       112
# t_cells              double_negative-stage3                    35
#                      double_negative-stage4b                  211
#                      double_negative-stage4c                   43
#                      double_positive                          381
#                      double_positive-proliferating            336
#                      immature_single_positive_cd8+            194
#                      single_positive_cd8+,_possibly_mature    117
# dtype: int64
#
# - Tongue -
# -- before cleaning --
#  annotation               subannotation
# Basal_cells              .                4242
# Maturing/nonkeratinized  .                1454
# Proliferating cells      .                 843
# keratinocytes            .                 962
# unknown_cell             .                  37
# dtype: int64
# 		--- after cleaning labels ---
# annotation               subannotation
# basal_cells              -                4242
# keratinocytes            -                 962
# maturing/nonkeratinized  -                1454
# proliferating_cells      -                 843
# unknown_cell             -                  37
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation     subannotation
# basal_cells    basal            4242
#                keratinocytes     962
#                proliferating     843
# keratinocytes  suprabasal       1454
# unknown_cells  -                  37
# dtype: int64
# --- after cleaning ---
#  annotation     subannotation
# basal          basal            4242
#                keratinocytes     962
#                proliferating     843
# keratinocytes  suprabasal       1454
# unknown        ..                 37
# dtype: int64
#
# - Trachea -
# -- before cleaning --
#  annotation      subannotation
# Epcam           .                 246
#                 Foxj1              20
#                 Krt5               36
#                 Krt5/Krt14        443
#                 Scgb1a1           140
# Pdgfrb          .                7904
# Pdgfrb + Ptprc  .                 543
# Pecam1          .                1039
# Ptprc           .                 898
# dtype: int64
# 		--- after cleaning labels ---
# annotation      subannotation
# epcam           -                 246
#                 foxj1              20
#                 krt5               36
#                 krt5/krt14        443
#                 scgb1a1           140
# pdgfrb          -                7904
# pdgfrb_+_ptprc  -                 543
# pecam1          -                1039
# ptprc           -                 898
# dtype: int64
# 			---- After tissue-specific cleaning ----
# annotation            subannotation
# endothelial_cells     -                  1039
# epithelial_cells      -                   246
#                       basal_cells          36
#                       ciliated_cells       20
#                       krt5/krt14          443
#                       secretory_cells     140
# immune_cells          -                   898
# neuroendocrine_cells  -                   543
# stromal_cells         -                  7904
# dtype: int64
# --- after cleaning ---
#  annotation      subannotation
# endothelial     ..                 1039
# epithelial      ..                  246
#                 basal_cells          36
#                 ciliated_cells       20
#                 krt5/krt14          443
#                 secretory_cells     140
# immune          ..                  898
# neuroendocrine  ..                  543
# stromal         ..                 7904
# dtype: int64
#                             annotation subannotation   tissue  \
# 10X_P4_3_AAAGTAGAGATGCCAG  mesenchymal             b  Bladder
# 10X_P4_3_AACCGCGTCCAACCAA  mesenchymal             a  Bladder
# 10X_P4_3_AACTCCCGTCGGGTCT  mesenchymal             a  Bladder
# 10X_P4_3_AACTCTTAGTTGCAGG      luminal             a  Bladder
# 10X_P4_3_AACTCTTTCATAACCG  mesenchymal             a  Bladder
#
#                           annotation_subannotation
# 10X_P4_3_AAAGTAGAGATGCCAG           mesenchymal: b
# 10X_P4_3_AACCGCGTCCAACCAA           mesenchymal: a
# 10X_P4_3_AACTCCCGTCGGGTCT           mesenchymal: a
# 10X_P4_3_AACTCTTAGTTGCAGG               luminal: a
# 10X_P4_3_AACTCTTTCATAACCG           mesenchymal: a

# %%
original_annotations = pd.concat(original_dfs)
print(original_annotations.shape)

# Drop the double-annotated heart and aorta annotations
original_annotations = original_annotations.loc[~original_annotations.index.duplicated()]
print(original_annotations.shape)
# original_annotations = original_annotations.drop('plate.barcode', axis=1)
# original_annotations.head()

combined_with_original = combined.join(original_annotations, rsuffix='_original', lsuffix='_cleaned')
print(combined_with_original.shape)
# combined_with_original.head()

cols = ['tissue', 'annotation_original', 'subannotation_original', 'annotation_cleaned', 'subannotation_cleaned',]

# combined_with_original.fillna('.').groupby(['tissue', 'annotation', 'subannotation', 'annotation_original', 'subannotation_original']).size()

combined_sizes = combined_with_original.fillna('.').groupby(cols).size().reset_index()
combined_sizes = combined_sizes.rename(columns={0: 'n_cells'})
print(combined_sizes.shape)

from IPython.display import display, HTML

for tissue, df in combined_sizes.groupby('tissue'):
    display(df)
# Out:
# (54837, 2)
# (54837, 2)
# (54837, 6)
# (125, 6)
#     tissue annotation_original subannotation_original annotation_cleaned  \
# 0  Bladder               Basal                      .              basal
# 1  Bladder   Endothelial cells                      .        endothelial
# 2  Bladder        Immune cells                      .             immune
# 3  Bladder           LuminalA1                      .            luminal
# 4  Bladder           LuminalA2                      .            luminal
# 5  Bladder            LuminalB                      .            luminal
# 6  Bladder       MesenchymalA1                      .        mesenchymal
# 7  Bladder       MesenchymalA2                      .        mesenchymal
# 8  Bladder       MesenchymalB1                      .        mesenchymal
# 9  Bladder       MesenchymalB2                      .        mesenchymal
#
#   subannotation_cleaned  n_cells
# 0                     .      266
# 1                     .       68
# 2                     .       57
# 3                     a      313
# 4                     a      219
# 5                     b      391
# 6                     a      169
# 7                     a      501
# 8                     b      187
# 9                     b      329
#    tissue    annotation_original subannotation_original annotation_cleaned  \
# 10  Heart            Blood_Cells                      .       erythrocytes
# 11  Heart                    CMs                      .     cardiomyocytes
# 12  Heart  Coronary_vascular_EDC                      .        endothelial
# 13  Heart        Endocardial_EDC                      .        endothelial
# 14  Heart                     Fb                      .        fibroblasts
# 15  Heart                 Fb_SMC             Fibroblast        fibroblasts
# 16  Heart                 Fb_SMC    Smooth_Muscle_Cells      smooth_muscle
#
#    subannotation_cleaned  n_cells
# 10                     .       55
# 11                     .       83
# 12     coronary_vascular      178
# 13           endocardial       65
# 14                     .      157
# 15                     .       65
# 16                     .       21
#     tissue          annotation_original subannotation_original  \
# 17  Kidney        Collecting duct cells                      .
# 18  Kidney  Feneserated capillary cells                      .
# 19  Kidney                  Fibroblasts                      .
# 20  Kidney                  Macrophages                      .
# 21  Kidney    Proximal ascending tubule                      .
# 22  Kidney          Smooth muscle cells                      .
# 23  Kidney       Thick Ascending tubule                      .
# 24  Kidney      connecting tubule cells                      .
# 25  Kidney            endothelial cells                      .
# 26  Kidney                 other immune                      .
# 27  Kidney             proximal tubule                       .
#
#        annotation_cleaned subannotation_cleaned  n_cells
# 17        collecting_duct                     .       72
# 18  fenestrated_capillary                     .      345
# 19            fibroblasts                     .      113
# 20            macrophages                     .      181
# 21                 tubule    proximal_ascending      352
# 22          smooth_muscle                     .       50
# 23                 tubule       thick_ascending      473
# 24                 tubule            connecting      245
# 25            endothelial                     .       45
# 26                 immune                     .       54
# 27                 tubule              proximal      851
#    tissue annotation_original subannotation_original annotation_cleaned  \
# 28  Liver     F-hep-midlobule            F-Hamp-high        hepatocytes
# 29  Liver   F-hep-pericentral         F-Cyp2e1, Glul        hepatocytes
# 30  Liver    F-hep-periportal               F-Cyp2f2        hepatocytes
# 31  Liver     M-hep-midlobule             M-Mup-high        hepatocytes
# 32  Liver   M-hep-pericentral         M-Cyp2e1, Glul        hepatocytes
# 33  Liver    M-hep-periportal               M-Cyp2f2        hepatocytes
# 34  Liver         endothelial                      .        endothelial
#
#    subannotation_cleaned  n_cells
# 28            midlobular       50
# 29           pericentral      258
# 30            periportal      203
# 31            midlobular      214
# 32           pericentral      115
# 33            periportal      166
# 34                     .       20
#    tissue                                annotation_original  \
# 35   Lung                               Alveolar Macrophages
# 36   Lung                                            B Cells
# 37   Lung                                     Ciliated Cells
# 38   Lung                                         Club Cells
# 39   Lung                                    Dendritic Cells
# 40   Lung                            Endothelial Cell Type I
# 41   Lung                           Endothelial Cell Type IV
# 42   Lung                            Interstital Macrophages
# 43   Lung                                         Mast Cells
# 44   Lung                                  Mesothelial Cells
# 45   Lung                                          Monocytes
# 46   Lung                               Natural Killer Cells
# 47   Lung          Potential Ciliated and Club Cell Doublets
# 48   Lung  Potential Stromal Cell Type V and Endothelial ...
# 49   Lung                                Stromal Cell Type I
# 50   Lung                               Stromal Cell Type II
# 51   Lung                               Stromal Cell Type IV
# 52   Lung                                Stromal Cell Type V
# 53   Lung                                            T Cells
# 54   Lung                  Type II Alveolar Epithelial Cells
# 55   Lung                                   Unknown Immune I
# 56   Lung                                  Unknown Immune II
#
#    subannotation_original annotation_cleaned subannotation_cleaned  n_cells
# 35                      .        macrophages              alveolar      345
# 36                      .            b_cells                     .      205
# 37                      .           ciliated                     .       41
# 38                      .               club                     .        5
# 39                      .          dendritic                     .      225
# 40                      .        endothelial                     .      349
# 41                      .        endothelial                     .       76
# 42                      .        macrophages          interstitial      111
# 43                      .               mast                     .       22
# 44                      .        mesothelial                     .       24
# 45                      .          monocytes                     .      145
# 46                      .     natural_killer                     .      832
# 47                      .            unknown                     .        8
# 48                      .            unknown                     .       41
# 49                      .            stromal                     .     1586
# 50                      .            stromal                     .      466
# 51                      .            stromal                     .      348
# 52                      .            stromal                     .      134
# 53                      .            t_cells                     .      246
# 54                      .         epithelial      alveolar_type_ii       89
# 55                      .             immune                     .      124
# 56                      .             immune                     .       27
#      tissue                          annotation_original  \
# 57  Mammary                                      B cells
# 58  Mammary                       Basal Epithelial cells
# 59  Mammary                            Endothelial cells
# 60  Mammary  Hormone responsive luminal epithelial cells
# 61  Mammary         Luminal epithelial progenitors Cd14+
# 62  Mammary                                  Macrophages
# 63  Mammary                          S100a4+/Ccl5+ cells
# 64  Mammary                                Stromal cells
# 65  Mammary                 Stromal cells Mustn1+/Procr+
# 66  Mammary                                      T cells
# 67  Mammary                                T cells Nkg7+
#
#    subannotation_original annotation_cleaned subannotation_cleaned  n_cells
# 57                      .            b_cells                     .      764
# 58                      .              basal                     .      393
# 59                      .        endothelial                     .      251
# 60                      .            luminal    hormone_responsive      190
# 61                      .            luminal           progenitors      240
# 62                      .        macrophages                     .      186
# 63                      .            stromal     s100a4+_and_ccl5+       57
# 64                      .            stromal                     .      581
# 65                      .            stromal    mustn1+_and_procr+       59
# 66                      .            t_cells                     .     1467
# 67                      .            t_cells                 nkg7+      293
#     tissue                  annotation_original subannotation_original  \
# 68  Marrow                         Erythrocytes                      .
# 69  Marrow  Erythroid-progenitors_Erythroblasts                      .
# 70  Marrow              Granulocyte-progenitors                      .
# 71  Marrow                         Granulocytes                      .
# 72  Marrow                           Immature-B                      .
# 73  Marrow                          Macrophages                      .
# 74  Marrow                             Mature-B                      .
# 75  Marrow            Megakaryocyte-progenitors                      .
# 76  Marrow                 Monocyte-progenitors                      .
# 77  Marrow                            Monocytes                      .
# 78  Marrow                              PreproB                      .
# 79  Marrow                     Stem_Progenitors                      .
# 80  Marrow                                T_NKT                      .
#
#    annotation_cleaned subannotation_cleaned  n_cells
# 68       erythrocytes                     .      142
# 69        progenitors             erythroid      268
# 70        progenitors           granulocyte      330
# 71       granulocytes                     .      770
# 72            b_cells              immature      299
# 73        macrophages                     .      222
# 74            b_cells                mature       91
# 75        progenitors         megakaryocyte       62
# 76        progenitors                mature      322
# 77          monocytes                     .      522
# 78            b_cells                prepro       63
# 79        progenitors                     .      399
# 80            t_cells                     .      162
#     tissue            annotation_original subannotation_original  \
# 81  Muscle                              .                      .
# 82  Muscle                        B cells                      .
# 83  Muscle                        T cells                      .
# 84  Muscle             chondrogenic cells                      .
# 85  Muscle              endothelial cells                      .
# 86  Muscle  fibro-/adipogenic progenitors                      .
# 87  Muscle                    macrophages                      .
# 88  Muscle                satellite cells                      .
#
#    annotation_cleaned subannotation_cleaned  n_cells
# 81            unknown                     .      312
# 82            b_cells                     .      463
# 83            t_cells                     .      323
# 84       chondrogenic                     .      380
# 85        endothelial                     .     1290
# 86   mesenchymal_stem                     .     1111
# 87        macrophages                     .      308
# 88          satellite                     .      349
#      tissue               annotation_original subannotation_original  \
# 89   Spleen               10. Dendritic cells                      .
# 90   Spleen         11. Proliferative B cells                      .
# 91   Spleen                 12. Macrophages 2                      .
# 92   Spleen                        13 T cells                      .
# 93   Spleen  14. Plasmocytoid Dendritic cells                      .
# 94   Spleen          2. Marginal Zone B cells                      .
# 95   Spleen                   3. CD8+ T Cells                      .
# 96   Spleen                   4. Cd4+ T cells                      .
# 97   Spleen                  6. Macrophages 1                      .
# 98   Spleen                        7. B cells                      .
# 99   Spleen           8. Natural Killer cells                      .
# 100  Spleen                      9. iNK cells                      .
# 101  Spleen          T1/T2/Follicular B cells                      .
#
#     annotation_cleaned     subannotation_cleaned  n_cells
# 89           dendritic                         .      102
# 90             b_cells             proliferative       98
# 91         macrophages                         .       96
# 92             t_cells                         .       92
# 93           dendritic              plasmocytoid       42
# 94             b_cells             marginal_zone     1440
# 95             t_cells                      cd8+      946
# 96             t_cells                      cd4+      905
# 97         macrophages                         .      299
# 98             b_cells                         .      282
# 99             t_cells      natural_killer_cells      224
# 100            t_cells  invariant_natural_killer      120
# 101            b_cells                follicular     4906
#      tissue         annotation_original                subannotation_original  \
# 102  Thymus                 DN-Stage 4c                                     .
# 103  Thymus                   DN-Stage3                                     .
# 104  Thymus                  DN-Stage4b                                     .
# 105  Thymus             immature SP Cd8                                     .
# 106  Thymus                mix of cells  Single positive Cd8, possibly mature
# 107  Thymus                mix of cells             stromal_mesenchymal cells
# 108  Thymus    stromal mesenchymal cell                                     .
# 109  Thymus                thymocyte-DP                                     .
# 110  Thymus  thymocyte-DP-proliferating                                     .
#
#       annotation_cleaned                  subannotation_cleaned  n_cells
# 102              t_cells                double_negative-stage4c       43
# 103              t_cells                 double_negative-stage3       35
# 104              t_cells                double_negative-stage4b      211
# 105              t_cells          immature_single_positive_cd8+      194
# 106              t_cells  single_positive_cd8+,_possibly_mature      117
# 107  stromal_mesenchymal                                      .       81
# 108  stromal_mesenchymal                                      .       31
# 109              t_cells                        double_positive      381
# 110              t_cells          double_positive-proliferating      336
#      tissue      annotation_original subannotation_original  \
# 111  Tongue              Basal_cells                      .
# 112  Tongue  Maturing/nonkeratinized                      .
# 113  Tongue      Proliferating cells                      .
# 114  Tongue            keratinocytes                      .
# 115  Tongue             unknown_cell                      .
#
#     annotation_cleaned subannotation_cleaned  n_cells
# 111              basal                 basal     4242
# 112      keratinocytes            suprabasal     1454
# 113              basal         proliferating      843
# 114              basal         keratinocytes      962
# 115            unknown                     .       37
#       tissue annotation_original subannotation_original annotation_cleaned  \
# 116  Trachea               Epcam                      .         epithelial
# 117  Trachea               Epcam                  Foxj1         epithelial
# 118  Trachea               Epcam                   Krt5         epithelial
# 119  Trachea               Epcam             Krt5/Krt14         epithelial
# 120  Trachea               Epcam                Scgb1a1         epithelial
# 121  Trachea              Pdgfrb                      .            stromal
# 122  Trachea      Pdgfrb + Ptprc                      .     neuroendocrine
# 123  Trachea              Pecam1                      .        endothelial
# 124  Trachea               Ptprc                      .             immune
#
#     subannotation_cleaned  n_cells
# 116                     .      246
# 117        ciliated_cells       20
# 118           basal_cells       36
# 119            krt5/krt14      443
# 120       secretory_cells      140
# 121                     .     7904
# 122                     .      543
# 123                     .     1039
# 124                     .      898

# %% [markdown]
# ### Write combined original vs cleaned

# %%
csv = os.path.join(summary_folder, 'maca_3month_original_vs_cleaned_10x.csv')
combined_sizes.to_csv(csv, index=False)

# %% [markdown]
# ## make sure there are no duplicated cell ids

# %%
combined.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Make sure there are 12 tissues

# %%
tissues = sorted(combined['tissue'].unique())
tissues
# Out:
# ['Bladder',
#  'Heart',
#  'Kidney',
#  'Liver',
#  'Lung',
#  'Mammary',
#  'Marrow',
#  'Muscle',
#  'Spleen',
#  'Thymus',
#  'Tongue',
#  'Trachea']

# %%
pd.Series(tissues)
# Out:
# 0     Bladder
# 1       Heart
# 2      Kidney
# 3       Liver
# 4        Lung
# 5     Mammary
# 6      Marrow
# 7      Muscle
# 8      Spleen
# 9      Thymus
# 10     Tongue
# 11    Trachea
# dtype: object

# %% [markdown]
#     0                    Aorta
#     1                  Bladder
#     2     Brain_FACS_microglia
#     3       Brain_FACS_neurons
#     4                    Colon
#     5                Diaphragm
#     6                      Fat
#     7                    Heart
#     8                   Kidney
#     9                    Liver
#     10                    Lung
#     11           Mammary_Gland
#     12                  Marrow
#     13                  Muscle
#     14                Pancreas
#     15                    Skin
#     16                  Spleen
#     17                  Thymus
#     18                  Tongue
#     19                 Trachea
#     dtype: object

# %%
combined.groupby('tissue').size()
# Out:
# tissue
# Bladder     2500
# Heart        624
# Kidney      2781
# Liver       1026
# Lung        5449
# Mammary     4481
# Marrow      3652
# Muscle      4536
# Spleen      9552
# Thymus      1429
# Tongue      7538
# Trachea    11269
# dtype: int64

# %%
pd.options.display.max_rows = 100

# %%
annotation_sizes = combined.groupby('annotation').size().sort_values(ascending=False).to_frame()
annotation_sizes = annotation_sizes.rename(columns={0: 'n_cells'})
print(annotation_sizes.shape)
annotation_sizes
# Out:
# (34, 1)
#                        n_cells
# annotation
# stromal                  11135
# b_cells                   8611
# basal                     6706
# t_cells                   6095
# endothelial               3381
# tubule                    1921
# macrophages               1748
# keratinocytes             1454
# progenitors               1381
# luminal                   1353
# mesenchymal               1186
# immune                    1160
# mesenchymal_stem          1111
# hepatocytes               1006
# epithelial                 974
# natural_killer             832
# granulocytes               770
# monocytes                  667
# neuroendocrine             543
# unknown                    398
# chondrogenic               380
# dendritic                  369
# satellite                  349
# fenestrated_capillary      345
# fibroblasts                335
# erythrocytes               197
# stromal_mesenchymal        112
# cardiomyocytes              83
# collecting_duct             72
# smooth_muscle               71
# ciliated                    41
# mesothelial                 24
# mast                        22
# club                         5

# %%
csv = os.path.join(summary_folder, 'maca_3month_annotation_counts_10x.csv')
annotation_sizes.to_csv(csv)

# %%
len(combined.groupby('tissue').size())
# Out:
# 12

# %% [markdown]
# ### Write annotations

# %%
csv = os.path.join(metadata_folder, 'maca_3month_annotations_10x.csv')

combined.to_csv(csv)

# %%
combined.groupby('annotation').apply(lambda x: len(x['annotation'].iloc[0])).sort_values(ascending=False)
# Out:
# annotation
# fenestrated_capillary    21
# stromal_mesenchymal      19
# mesenchymal_stem         16
# collecting_duct          15
# neuroendocrine           14
# cardiomyocytes           14
# natural_killer           14
# keratinocytes            13
# smooth_muscle            13
# granulocytes             12
# chondrogenic             12
# erythrocytes             12
# progenitors              11
# mesothelial              11
# mesenchymal              11
# macrophages              11
# endothelial              11
# hepatocytes              11
# fibroblasts              11
# epithelial               10
# satellite                 9
# monocytes                 9
# dendritic                 9
# ciliated                  8
# unknown                   7
# luminal                   7
# stromal                   7
# t_cells                   7
# b_cells                   7
# immune                    6
# tubule                    6
# basal                     5
# club                      4
# mast                      4
# dtype: int64
